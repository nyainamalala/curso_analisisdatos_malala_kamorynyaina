# %%
import matplotlib.pyplot as plt
import numpy as np
import pandas as pd
plt.style.use('seaborn-v0_8-whitegrid')
plt.rcParams['figure.figsize'] = (5,4)
plt.rcParams['figure.dpi'] = 120

# %% [markdown]
# ## LINEAS

# %%
plt.plot([1.5, 3.0])

# %%
plt.plot([1.5, 3.0])
plt.title("Interactive Plot")
plt.xlabel("X-axis")
plt.ylabel("Y-axis")
# Out:
# Text(0, 0.5, 'Y-axis')

# %%
plt.plot([1.5, 3.0])
plt.plot([3.5, 2.5])
plt.title("Interactive Plot")
plt.xlabel("X-axis")
plt.ylabel("Y-axis")
# Out:
# Text(0, 0.5, 'Y-axis')

# %%
arr = np.loadtxt('data.txt', delimiter = ',')
print(arr)
plt.plot(arr)
# Out:
# [ 1.  1.  2.  4.  3.  9.  4. 16.  5. 25.]

# %%
arr = np.loadtxt('data.txt', delimiter = ',')
print(arr)
plt.plot(arr)
# Out:
# [ 1.  1.  2.  4.  3.  9.  4. 16.  5. 25.]

# %%
arr_2d = arr.reshape(5,2)
print(arr_2d)
plt.plot(arr_2d)
# Out:
# [[ 1.  1.]
#  [ 2.  4.]
#  [ 3.  9.]
#  [ 4. 16.]
#  [ 5. 25.]]
# [<matplotlib.lines.Line2D at 0x1f4b70d8d00>,
#  <matplotlib.lines.Line2D at 0x1f4b70d8d60>]

# %%
x = arr_2d[:,0]
y = arr_2d[:,1]
print(x, y)
# Out:
# [1. 2. 3. 4. 5.] [ 1.  4.  9. 16. 25.]

# %%
plt.plot(x, y)

# %%
x, y = np.loadtxt('data.csv', unpack = True, usecols = (0,1), delimiter = ',')
print(x)
print(y)
plt.plot(x, y)
# Out:
# [1. 2. 3. 4. 5.]
# [ 1.  4.  9. 16. 25.]

# %%
plt.plot(x, y, 'r--')

# %%
plt.plot(y, x, 'g*-');

# %%
df = pd.read_csv("../data/AMC.csv", sep=',', encoding="utf-8", skipinitialspace=True,
                 index_col='Date', parse_dates=True)
df.head()
