# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

# %%
df = pd.read_csv('../../data/tips.csv')
df.head(2)
# Out:
#    total_bill   tip     sex smoker  day    time  size
# 0       16.99  1.01  Female     No  Sun  Dinner     2
# 1         NaN  1.66    Male     No  Sun  Dinner     3

# %%
# 1: SERIE PANDAS
plt.hist(df['tip'])
# Out:
# (array([41., 79., 66., 27., 19.,  5.,  4.,  1.,  1.,  1.]),
#  array([ 1. ,  1.9,  2.8,  3.7,  4.6,  5.5,  6.4,  7.3,  8.2,  9.1, 10. ]),
#  <BarContainer object of 10 artists>)

# %%
# 2 ARRAY NUMPY
plt.plot(df['tip'].values)

# %%
# 3 para ver que tipo es
type(df['tip'].values)
# Out:
# numpy.ndarray

# %%
df.groupby('time')['tip'].sum()
# Out:
# time
# Dinner    546.07
# Lunch     185.51
# Name: tip, dtype: float64

# %%
df_tip_by_time = pd.DataFrame(df.groupby('time')['tip'].sum()).reset_index()
df_tip_by_time
# Out:
#      time     tip
# 0  Dinner  546.07
# 1   Lunch  185.51

# %%
# .bar: horizontal
plt.bar(df['time'], df['tip'], color ="red")
plt.title('Pour boire para heure', size=28, c='b')
plt.ylabel('Horaire', size=26, c='y') # c: color 
plt.xlabel('Argent de poche', size=28, c='y')
# Out:
# Text(0.5, 0, 'Argent de poche')

# %%
# .barh: vertical
plt.barh(df['time'], df['tip'], color ="aquamarine")
plt.title('Propinas por horario', size=30, c='b')
plt.ylabel('Horario', size=18, c='r') # c: color 
plt.xlabel('Dineritos', size=28, c='y')
# Out:
# Text(0.5, 0, 'Dineritos')

# %%
bars = plt.bar(df_tip_by_time['time'], df_tip_by_time['tip'])
labels = [str(bar.get_height()) for bar in bars]
plt.legend(bars, labels)

# %%
# HISTOGRAMA
df.hist()
# Out:
# array([[<Axes: title={'center': 'total_bill'}>,
#         <Axes: title={'center': 'tip'}>],
#        [<Axes: title={'center': 'size'}>, <Axes: >]], dtype=object)

# %%
# Histogram directamente con pandas
df = pd.read_csv('../../data/titanic.csv')
# df.hist(figsize)
df.hist(figsize=(10, 10))
# Out:
# array([[<Axes: title={'center': 'survived'}>,
#         <Axes: title={'center': 'pclass'}>],
#        [<Axes: title={'center': 'age'}>,
#         <Axes: title={'center': 'sibsp'}>],
#        [<Axes: title={'center': 'parch'}>,
#         <Axes: title={'center': 'fare'}>]], dtype=object)

# %%
plt.figure(figsize=(5,3))
plt.hist(df['age'], bins=15) # bins te da más detalle(5, 15, 20, 50, lo que quieras)
# Out:
# (array([ 44.,  24.,  32., 104., 115., 127.,  80.,  59.,  49.,  30.,  22.,
#          17.,   4.,   6.,   1.]),
#  array([ 0.42      ,  5.72533333, 11.03066667, 16.336     , 21.64133333,
#         26.94666667, 32.252     , 37.55733333, 42.86266667, 48.168     ,
#         53.47333333, 58.77866667, 64.084     , 69.38933333, 74.69466667,
#         80.        ]),
#  <BarContainer object of 15 artists>)

# %%
df.hist(bins=30, alpha=0.6, color='b', edgecolor='k', linewidth=1.5, figsize=(10,7), layout=(3,2))
plt.suptitle('Histogramas para columna del dataFrame')
plt.tight_layout()

# %%
df = pd.read_csv('../../data/tips.csv')
plt.scatter(df['total_bill'], df['tip'])
plt.grid(alpha=0.3) # cambiar mazava na somary maizina ny cadre kely ireny

# %%
plt.boxplot(df['tip'])
# Out:
# {'whiskers': [<matplotlib.lines.Line2D at 0x1915a146c50>,
# ...
#  'caps': [<matplotlib.lines.Line2D at 0x1915a1454e0>,
# ...
#  'boxes': [<matplotlib.lines.Line2D at 0x19159da6080>],
#  'medians': [<matplotlib.lines.Line2D at 0x1915a147970>],
#  'fliers': [<matplotlib.lines.Line2D at 0x1915a146d70>],
#  'means': []}

# %%
plt.boxplot(df['tip'], showmeans=True) # son lo mismo
plt.grid()

# %%
df = pd.read_csv('../../data/tips.csv')
plt.scatter(df['total_bill'], df['tip'])
plt.grid(alpha=0.3)
plt.savefig('example1.pdf', dpi=50)

# %%
df = pd.read_csv('../../data/tips.csv')
plt.violinplot(df['tip'])
# Out:
# {'bodies': [<matplotlib.collections.PolyCollection at 0x19159e8c070>],
#  'cmaxes': <matplotlib.collections.LineCollection at 0x19159e4bfa0>,
#  'cmins': <matplotlib.collections.LineCollection at 0x19159e8c670>,
#  'cbars': <matplotlib.collections.LineCollection at 0x19159e8c9d0>}

# %%
df = pd.read_csv('../../data/tips.csv').dropna()
fig, (ax1, ax2, ax3) = plt.subplots(nrows=1, ncols=3, figsize=(10,5))

ax1.violinplot(df['tip'], showmedians=True)
ax1.set_title('tip')

ax2.violinplot(df['total_bill'].dropna(), showmedians=True)
ax2.set_title('total_bill')

ax3.violinplot(df['size'].dropna(), showmedians=True)
ax3.set_title('size')

# plt.savefig('violin_plots_tips.png')

# plt.savefig('violin_plots_tips_.png)
# Out:
# Text(0.5, 1.0, 'size')

# %%
df = pd.read_csv('../../data/tips.csv').dropna()

# ver los valores unicos para cada columna

print(df['sex'].unique())
print(df['time'].unique())
print(df['smoker'].unique())
print(df['day'].unique())

#tranformar las columnas de texto a númerico: .map
df['sex'].map({'Female':1, 'Male':2})
df.head(5)
# calcular correlaciones

# mostrar las correlaciones con matplotlib
# Out:
# ['Female' 'Male']
# ['Dinner' 'Lunch']
# ['No' 'Yes']
# ['Sun' 'Sat' 'Thur' 'Fri']
#    total_bill   tip     sex smoker  day    time  size
# 0       16.99  1.01  Female     No  Sun  Dinner     2
# 2       21.01  3.50    Male     No  Sun  Dinner     3
# 3       23.68  3.31    Male     No  Sun  Dinner     2
# 4       24.59  3.61  Female     No  Sun  Dinner     4
# 5       25.29  4.71    Male     No  Sun  Dinner     4

# %%
# crear una función que reciba un DataFrame y devuelva ese DataFrame
# con todas las columnas de tipo texto mapeadas a númerico

# %%
df['time'] = df['time'].map({'Dinner':0, 'Lunch':1})
df.head(5)
# Out:
#    total_bill   tip     sex smoker  day  time  size
# 0       16.99  1.01  Female     No  Sun     0     2
# 2       21.01  3.50    Male     No  Sun     0     3
# 3       23.68  3.31    Male     No  Sun     0     2
# 4       24.59  3.61  Female     No  Sun     0     4
# 5       25.29  4.71    Male     No  Sun     0     4

# %%
df['sex'] = df['sex'].map({'Female':1, 'Male':2})
df.head(5)
# Out:
#    total_bill   tip  sex smoker  day  time  size
# 0       16.99  1.01    1     No  Sun     0     2
# 2       21.01  3.50    2     No  Sun     0     3
# 3       23.68  3.31    2     No  Sun     0     2
# 4       24.59  3.61    1     No  Sun     0     4
# 5       25.29  4.71    2     No  Sun     0     4

# %%
df['smoker'] = df['smoker'].map({'No':3, 'Yes':4})
df.head(5)
# Out:
#    total_bill   tip  sex  smoker  day  time  size  somker
# 0       16.99  1.01    1       3  Sun     0     2       3
# 2       21.01  3.50    2       3  Sun     0     3       3
# 3       23.68  3.31    2       3  Sun     0     2       3
# 4       24.59  3.61    1       3  Sun     0     4       3
# 5       25.29  4.71    2       3  Sun     0     4       3

# %%
df['day'] = df['day'].map({'Sun':7, 'sat':6, 'Thur':4, 'Frid':5})
df.head(5)
# Out:
#    total_bill   tip  sex  smoker  day  time  size  somker
# 0       16.99  1.01    1       3  7.0     0     2       3
# 2       21.01  3.50    2       3  7.0     0     3       3
# 3       23.68  3.31    2       3  7.0     0     2       3
# 4       24.59  3.61    1       3  7.0     0     4       3
# 5       25.29  4.71    2       3  7.0     0     4       3

# %%
corr =df.corr()


plt.imshow(df_corr, cmap='viridis')
plt.colorbar()
plt.xticks(range(len(df_corr)), df_corr.columns, rotation=20)
plt.yticks(range(len(df_corr)), df_corr.columns)
# Out:
# ([<matplotlib.axis.YTick at 0x1915b910bb0>,
# ...
#  [Text(0, 0, 'total_bill'),
#   Text(0, 1, 'tip'),
#   Text(0, 2, 'sex'),
#   Text(0, 3, 'smoker'),
#   Text(0, 4, 'day'),
#   Text(0, 5, 'time'),
#   Text(0, 6, 'size')])

# %%
df = pd.read_csv('../../data/tips.csv').dropna()

# ver los valores unicos para cada columna

print(df['sex'].unique())
print(df['time'].unique())
print(df['smoker'].unique())
print(df['day'].unique())

#tranformar las columnas de texto a númerico: .map
df['sex'] = df['sex'].map({
    'Female':1, 
    'Male':2
})

df['time'] = df['time'].map({
    'Dinner':1, 
    'Lunch':2
})

df['smoker'] = df['smoker'].map({
    'No':1, 
    'Yes':2
})

df['day'] = df['day'].map({
    'Sun':7,
    'Sat':6,
    'Thur':4,
    'Frid':5
})


# calcular correlaciones
df_corr = df.corr()
corr =df.corr()

# mostrar las correlaciones con matplotlib

plt.imshow(df_corr, cmap='viridis')
plt.colorbar()
plt.xticks(range(len(df_corr)), df_corr.columns, rotation=20)
plt.yticks(range(len(df_corr)), df_corr.columns);
# Out:
# ['Female' 'Male']
# ['Dinner' 'Lunch']
# ['No' 'Yes']
# ['Sun' 'Sat' 'Thur' 'Fri']

# %%
# crear una nueva columna por cad aposible valor d elas columnas texto utilizando
# get_dummies()

df = pd.read_csv('../../data/tips.csv').dropna()
df = pd.get_dummies(df)
df_corr = df.corr()

plt.figure(figsize=(10,7), dpi=300)
plt.imshow(df_corr, cmap='viridis')
plt.colorbar()
plt.xticks(range(len(df_corr)), df_corr.columns, rotation=20)
plt.yticks(range(len(df_corr)), df_corr.columns);

# le point virgule quita los codigos que te da mareo
